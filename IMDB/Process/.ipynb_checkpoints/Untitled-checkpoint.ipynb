# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# result = requests.get('https://www.imdb.com/search/title/?groups=top_250&sort=user_rating')
# result2 = requests.get('https://www.imdb.com/search/title/?groups=top_250&sort=user_rating,desc&start=51&ref_=adv_nxt')
# result3 = requests.get('https://www.imdb.com/search/title/?groups=top_250&sort=user_rating,desc&start=101&ref_=adv_nxt')
# result4 = requests.get('https://www.imdb.com/search/title/?groups=top_250&sort=user_rating,desc&start=151&ref_=adv_nxt')
result5 = requests.get('https://www.imdb.com/search/title/?groups=top_250&sort=user_rating,desc&start=201&ref_=adv_nxt')

src = result5.content
soup = BeautifulSoup(src, 'lxml')

# %%
df = pd.DataFrame()

# %%
# TITLE
images = soup.find_all('img', class_='loadlate') #['alt'], berisi title
title = []
for image in images:
    title.append(image['alt'])
len(title)
df['Title'] = title

# %%
# DESCRIPTION
description = []
descs = soup.find_all('p', class_='text-muted')
for i in range(len(descs)):
    if (i % 2) != 0:
        description.append(descs[i].text)
df['Description'] = description
df['Description'] = df['Description'].apply(lambda ser: ser[5:])

# %%
# RUNTIME, GENRE
runtimes = []
genres = []
for i in range(len(descs)):
    if (i % 2) == 0:
        for runtime in descs[i].find_all('span', class_='runtime'):
            runtimes.append(runtime.text)
        for genre in descs[i].find_all('span', class_='genre'):
            genres.append(genre.text)
df['Runtime'] = runtimes
df['Genre'] = genres

# %%
df['Runtime'] = df['Runtime'].apply(lambda ser: int(ser[:3]))
df['Genre'] = df['Genre'].apply(lambda ser: ser[1:])

# %%
# YEAR
years = []
for year in soup.find_all('span', class_='lister-item-year'):
    years.append(year.text)
df['Year'] = years

# %%
df['Year'] = df['Year'].apply(lambda ser: ser.replace('(', '').replace(')', ''))
# df['Year'].loc[2] = '2019'
# df['Year'] = df['Year'].astype('int64')

# %%
df
# Out:
#                                            Title  \
# 0                                            Ran
# 1                                    Raging Bull
# 2                                        Stalker
# 3                Monty Python and the Holy Grail
# 4                                      Chinatown
# 5                                  Andrei Rublev
# 6                               The Great Escape
# 7                          El ángel exterminador
# 8                                        Yôjinbô
# 9                          Judgment at Nuremberg
# 10                              Some Like It Hot
# 11                               Smultronstället
# 12                           Det sjunde inseglet
# 13                             Dial M for Murder
# 14                              Tôkyô monogatari
# 15                               Ace in the Hole
# 16                                      Rashômon
# 17                                 All About Eve
# 18                                    White Heat
# 19              The Treasure of the Sierra Madre
# 20                                 The Red Shoes
# 21                    La passion de Jeanne d'Arc
# 22                                 The Gold Rush
# 23                                  Sherlock Jr.
# 24                                     Ah-ga-ssi
# 25                                         Logan
# 26                              Relatos salvajes
# 27                      The Grand Budapest Hotel
# 28                                     Gone Girl
# 29                                 Hacksaw Ridge
# 30                              12 Years a Slave
# 31                                          Rush
# 32                                     Spotlight
# 33                                      The Help
# 34                                     Prisoners
# 35                            Mad Max: Fury Road
# 36                                   A Wednesday
# 37                                   Gran Torino
# 38  Harry Potter and the Deathly Hallows: Part 2
# 39                                Shutter Island
# 40                           Hachi: A Dog's Tale
# 41                                  Mary and Max
# 42                      How to Train Your Dragon
# 43                                 Into the Wild
# 44                        No Country for Old Men
# 45                           There Will Be Blood
# 46                           Million Dollar Baby
# 47                                  Hotel Rwanda
# 48                                Salinui chueok
# 49                                  Mou gaan dou
#
#                                           Description  Runtime  \
# 0   In Medieval Japan, an elderly warlord retires,...      162
# 1   The life of boxer Jake LaMotta, whose violence...      129
# 2   A guide leads two men through an area known as...      162
# 3   King Arthur and his Knights of the Round Table...       91
# 4   A private detective hired to expose an adulter...      130
# 5   The life, times and afflictions of the fifteen...      205
# 6   Allied prisoners of war plan for several hundr...      172
# 7   The guests at an upper-class dinner party find...       95
# 8   A crafty ronin comes to a town divided by two ...      110
# 9   In 1948, an American court in occupied Germany...      179
# 10  When two male musicians witness a mob hit, the...      121
# 11  After living a life marked by coldness, an agi...       91
# 12  A man seeks answers about life, death, and the...       96
# 13  A tennis player frames his unfaithful wife for...      105
